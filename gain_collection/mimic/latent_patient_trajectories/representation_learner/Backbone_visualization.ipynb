# %%
import pickle
import numpy as np
metrics = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/919save/2/0.1/dis/test_perf_metrics.pkl','rb'))

# %%
metrics[1]['disch_24h', 'AUROC (ovr; all)']
# Out:
# NO_DISCH                     0.481847
# HOME HEALTH CARE             0.534774
# HOME                         0.545148
# SNF                          0.617744
# REHAB/DISTINCT PART HOSP     0.532768
# LONG TERM CARE HOSPITAL      0.345848
# DISC-TRAN CANCER/CHLDRN H    0.733180
# SHORT TERM HOSPITAL          0.391690
# DISCH-TRAN TO PSYCH HOSP     0.373789
# HOSPICE-HOME                 0.261489
# LEFT AGAINST MEDICAL ADVI    0.209309
# HOSPICE-MEDICAL FACILITY     0.782369
# HOME WITH HOME IV PROVIDR    0.597918
# ICF                          0.948141
# dtype: float64

# %%
metrics[1]['disch_24h', 'AUROC (ovr; all)']
# Out:
# NO_DISCH                     0.481847
# HOME HEALTH CARE             0.534774
# HOME                         0.545148
# SNF                          0.617744
# REHAB/DISTINCT PART HOSP     0.532768
# LONG TERM CARE HOSPITAL      0.345848
# DISC-TRAN CANCER/CHLDRN H    0.733180
# SHORT TERM HOSPITAL          0.391690
# DISCH-TRAN TO PSYCH HOSP     0.373789
# HOSPICE-HOME                 0.261489
# LEFT AGAINST MEDICAL ADVI    0.209309
# HOSPICE-MEDICAL FACILITY     0.782369
# HOME WITH HOME IV PROVIDR    0.597918
# ICF                          0.948141
# dtype: float64

# %%
import pickle
# test_perf_metrics.pkl
# test_reprs.pkl
# test_task_info.pkl
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/919save/2/0.1/dis/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/919save/2/0.1/dis/wbm/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
X = pr
y = t_info[1]['disch_48h', 'AUROC (ovr; all)'][1][:1024][:,0]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16,8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = t_info[1]['disch_48h', 'AUROC (ovr; all)'][0][:1024][:,0]
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()

# %%
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/919save/6/0.1/dis/test_task_info.pkl','rb')
t_info = pickle.load(task_info)

# %%
t_info[1]['disch_24h'][0].shape
# Out:
# (2180, 20)

# %%
from collections import Counter

# %%
Counter(t_info[1]['disch_24h'][1])
# Out:
# Counter({0: 1427,
#          2: 195,
#          1: 122,
#          -9223372036854775808: 243,
#          3: 83,
#          4: 52,
#          7: 10,
#          8: 8,
#          13: 3,
#          9: 13,
#          10: 4,
#          6: 14,
#          12: 2,
#          15: 1,
#          11: 3})

# %%
t_info[1]['disch_24h'][0][0]
# Out:
# array([ 8.6633835 ,  5.1640806 ,  3.062428  ,  2.5596752 ,  3.4285784 ,
#        -4.6924434 , -1.6243703 ,  0.7357322 ,  1.89546   ,  0.7150885 ,
#         1.3146397 ,  0.87666285, -2.3288543 ,  0.2502296 , -6.0281134 ,
#        -2.7685173 , -3.334449  , -3.3097744 , -3.0421848 , -5.748308  ],
#       dtype=float32)

# %%
Counter(np.argmax(t_info[1]['disch_24h'][0][:,:20], axis=1))
# Out:
# Counter({0: 1772, 2: 142, 1: 142, 4: 49, 7: 6, 3: 63, 9: 5, 10: 1})

# %%
t_info[1]['disch_24h'][0][:1024].shape
# Out:
# (1024, 20)

# %%
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/919save/6/0.1/dis/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
X = pr
y = t_info[1]['disch_24h'][1][:1024]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16,8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = np.argmax(t_info[1]['disch_24h'][0][:1024], axis=1)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()

# %%
metrics[1]['tasks_binary_multilabel', 'AUROC (all)']
# Out:
# mort_24h               0.764669
# mort_48h               0.333049
# dnr_24h                0.638161
# dnr_48h                0.549053
# cmo_24h                0.614167
# cmo_48h                0.681039
# Long LOS               0.566048
# icd_infection          0.433263
# icd_neoplasms          0.512319
# icd_endocrine          0.530807
# icd_blood              0.550296
# icd_mental             0.436706
# icd_nervous            0.464382
# icd_circulatory        0.418126
# icd_respiratory        0.558048
# icd_digestive          0.512039
# icd_genitourinary      0.436408
# icd_pregnancy          0.544663
# icd_skin               0.523003
# icd_musculoskeletal    0.515880
# icd_congenital         0.473950
# icd_perinatal               NaN
# icd_ill_defined        0.419675
# icd_injury             0.501502
# icd_unknown                 NaN
# Readmission 30         0.509104
# dtype: float64

# %%
t_info[1].keys()
# Out:
# dict_keys(['next_timepoint', 'Final Acuity Outcome', 'disch_24h', 'next_timepoint_was_measured', 'disch_48h', 'tasks_binary_multilabel'])

# %%
t_info[1].keys()
# Out:
# dict_keys(['next_timepoint', 'Final Acuity Outcome', 'disch_24h', 'next_timepoint_was_measured', 'disch_48h', 'tasks_binary_multilabel'])

# %%
            # self.task_dims = {
            #     'disch_24h': 20,
            #     'disch_48h': 20,
            #     'Final Acuity Outcome': 20,
            #     'tasks_binary_multilabel': 26, #7, # ICD10, los, readmission
            #     'next_timepoint': 56, # TODO put in config
            #     'next_timepoint_was_measured': 56,
            #     'masked_imputation': 56*2,
            # }

# %%
import pickle
from collections import Counter
# test_perf_metrics.pkl
# test_reprs.pkl
# test_task_info.pkl
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/919save/3/0.75/los/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]

# %%
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/919save/3/0.75/los/test_task_info.pkl','rb')
t_info = pickle.load(task_info)

# %%
# for i in range (56):
#     print("index is", i , Counter(t_info[1]['next_timepoint_was_measured'][1][:,i]))

# %%
t_info[1]['next_timepoint_was_measured'][1][:,8]
# Out:
# array([1., 1., 0., ..., 0., 0., 0.], dtype=float32)

# %%
X = pr
y = t_info[1]['tasks_binary_multilabel'][1][:1024][:,6]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16, 8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = t_info[1]['tasks_binary_multilabel'][0][:1024][:,6]
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()

# %%
X = pr
y = t_info[1]['tasks_binary_multilabel'][0][:1024][:,6]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(8, 8))
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()

# %%
import pickle
# test_perf_metrics.pkl
# test_reprs.pkl
# test_task_info.pkl
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/926save/0.25/morwbm/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/926save/0.25/morwbm/test_task_info.pkl','rb')
t_info = pickle.load(task_info)

# %%
X = pr
y = t_info[1]['tasks_binary_multilabel'][1][:1024][:,0]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16,8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = t_info[1]['tasks_binary_multilabel'][0][:1024][:,0]
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()

# %%
t_info[1]['tasks_binary_multilabel'][0][:1024][:,0][t_info[1]['tasks_binary_multilabel'][0][:1024][:,0] > 0]
# Out:
# array([2.3882494 , 0.6628763 , 0.800827  , 1.774627  , 0.61522865,
#        0.38240188, 0.18572855, 0.7177726 , 1.0335395 , 1.8061694 ,
#        0.6283529 , 1.5916843 , 0.36847094, 0.4470178 , 1.2188708 ,
#        1.7389953 , 1.4773548 , 0.6768121 , 0.944957  , 0.67913246,
#        1.1834099 , 0.6878519 , 2.0492663 , 0.2048516 , 1.9756238 ,
#        0.16313693, 1.0596514 , 2.0834894 , 0.24903163, 1.2448069 ,
#        0.06411755, 0.23703319, 0.41609105, 2.118389  , 0.75952655,
#        0.8502353 , 0.771785  ], dtype=float32)

# %%
import pickle
# test_perf_metrics.pkl
# test_reprs.pkl
# test_task_info.pkl
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/wbm/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/wbm/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
X = pr
y = t_info[1]['tasks_binary_multilabel'][1][:1024][:,0]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16,8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = t_info[1]['tasks_binary_multilabel'][0][:1024][:,0]
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()

# %%
import pickle
# test_perf_metrics.pkl
# test_reprs.pkl
# test_task_info.pkl
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/morwbm/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/morwbm/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
X = pr
y = t_info[1]['tasks_binary_multilabel'][1][:1024][:,0]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16,8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = t_info[1]['tasks_binary_multilabel'][0][:1024][:,0]
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()

# %%
Counter(t_info[1]['tasks_binary_multilabel'][1][:1024][:,0])
# Out:
# Counter({0.0: 1010, 1.0: 14})

# %%
import pickle
# test_perf_metrics.pkl
# test_reprs.pkl
# test_task_info.pkl
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/morwbm/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/morwbm/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
X = pr
y = t_info[1]['next_timepoint_was_measured'][1][:1024][:,16]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16,8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = t_info[1]['next_timepoint_was_measured'][0][:1024][:,16]
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()

# %%
import pickle
# test_perf_metrics.pkl
# test_reprs.pkl
# test_task_info.pkl
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/wbm/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/wbm/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
X = pr
y = t_info[1]['next_timepoint_was_measured'][1][:1024][:,16]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16,8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = t_info[1]['next_timepoint_was_measured'][0][:1024][:,16]
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()

# %%
import pickle
# test_perf_metrics.pkl
# test_reprs.pkl
# test_task_info.pkl
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.01/wbm/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.01/wbm/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
test_metrics = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.01/wbm/test_perf_metrics.pkl','rb'))
X = pr
y = t_info[1]['next_timepoint_was_measured'][1][:1024][:,16]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16,8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = t_info[1]['next_timepoint_was_measured'][0][:1024][:,16]
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()

# %%
import pickle
# test_perf_metrics.pkl
# test_reprs.pkl
# test_task_info.pkl
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/wbm/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/wbm/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
X = pr
y = t_info[1]['tasks_binary_multilabel'][1][:1024][:,0]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16,8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = t_info[1]['tasks_binary_multilabel'][0][:1024][:,0]
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()

# %%
df.loc[0].drop('group').values.flatten().tolist()
# Out:
# [38.0, 29, 8, 7, 28]

# %%
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/wbm/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/wbm/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
test_metrics = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/wbm/test_perf_metrics.pkl','rb'))
test_metrics_reverse = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/926save/0.25/morwbm/test_perf_metrics.pkl','rb'))
test_metrics_mor = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/morwbm/test_perf_metrics.pkl','rb'))

# %%
for i in range (56):
    print("index is", i ,categories[i], Counter(t_info[1]['next_timepoint_was_measured'][1][:,i]))
# index is 5 sodium Counter({0.0: 1994, 1.0: 186})
# index is 6 calcium Counter({0.0: 2041, 1.0: 139})
# index is 7 glascow coma scale total Counter({0.0: 1777, 1.0: 403})
# index is 8 glucose Counter({0.0: 1640, 1.0: 540})
# index is 9 lactic acid Counter({0.0: 2138, 1.0: 42})
# index is 10 cardiac output thermodilution Counter({0.0: 2086, 1.0: 94})
# index is 11 partial pressure of carbon dioxide Counter({0.0: 2019, 1.0: 161})
# index is 12 ph Counter({0.0: 1995, 1.0: 185})
# index is 13 tidal volume set Counter({0.0: 2083, 1.0: 97})
# index is 14 co2 (etco2, pco2, etc.) Counter({0.0: 2019, 1.0: 161})
# index is 15 respiratory rate Counter({1.0: 2033, 0.0: 147})
# index is 16 temperature Counter({0.0: 1489, 1.0: 691})
# Out:
# index is 0 mean corpuscular hemoglobin Counter({0.0: 2071, 1.0: 109})
# index is 1 anion gap Counter({0.0: 2020, 1.0: 160})
# index is 2 partial pressure of oxygen Counter({0.0: 2084, 1.0: 96})
# index is 3 phosphorous Counter({0.0: 2068, 1.0: 112})
# index is 4 positive end-expiratory pressure set Counter({0.0: 2021, 1.0: 159})
# index is 5 sodium Counter({0.0: 1994, 1.0: 186})
# index is 6 calcium Counter({0.0: 2041, 1.0: 139})
# index is 7 glascow coma scale total Counter({0.0: 1777, 1.0: 403})
# index is 8 glucose Counter({0.0: 1640, 1.0: 540})
# index is 9 lactic acid Counter({0.0: 2138, 1.0: 42})
# index is 10 cardiac output thermodilution Counter({0.0: 2086, 1.0: 94})
# index is 11 partial pressure of carbon dioxide Counter({0.0: 2019, 1.0: 161})
# index is 12 ph Counter({0.0: 1995, 1.0: 185})
# index is 13 tidal volume set Counter({0.0: 2083, 1.0: 97})
# index is 14 co2 (etco2, pco2, etc.) Counter({0.0: 2019, 1.0: 161})
# ...

# %%
# print(test_metrics[1]['next_timepoint_was_measured', 'AUROC (all)'].values)
# print(test_metrics_reverse[1]['next_timepoint_was_measured', 'AUROC (all)'].values)
# print(test_metrics_mor[1]['next_timepoint_was_measured', 'AUROC (all)'].values)
# print(list(test_metrics[1]['next_timepoint_was_measured', 'AUROC (all)'].keys()))

# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
# number of variable
# 变量类别
plt.figure(figsize=(20,20))
categories = np.array(list(test_metrics[1]['next_timepoint_was_measured', 'AUROC (all)'].keys()))[:,0]
N = len(categories)
# plot the first line of the data frame.
values1 = test_metrics[1]['next_timepoint_was_measured', 'AUROC (all)'].values
values2 = test_metrics_reverse[1]['next_timepoint_was_measured', 'AUROC (all)'].values
values3 = test_metrics_mor[1]['next_timepoint_was_measured', 'AUROC (all)'].values
# 将第一个值放到最后，以封闭图形
print(values)

# 设置每个点的角度值
angles = [n / float(N) * 2 * pi for n in range(N)]
# angles += angles[:1]

# Initialise the spider plot
# 初始化极坐标网格
ax = plt.subplot(111, polar=True)

# Draw one axe per variable + add labels labels yet
# 设置x轴的标签
plt.xticks(angles[:-1], categories, color='red', size=10)

# Draw ylabels
# 设置标签显示位置
ax.set_rlabel_position(0)
# 设置y轴的标签
plt.yticks([0.5, 0.75, 1], ["0.5", "0.75", "1"], color="blue", size=15)
plt.ylim(0, 1)

# Plot data
# 画图
ax.plot(angles, values1, linewidth=1,label = 'wbm only', linestyle='solid')
ax.plot(angles, values2, linewidth=1,label = 'wbm + mor reverse', linestyle='solid')
ax.plot(angles, values3, linewidth=1,label = 'wbm + mor', linestyle='solid')
# Fill area
# 填充区域
ax.fill(angles, values1, 'b', alpha=0.1)
ax.fill(angles, values2, 'r', alpha=0.1)
ax.fill(angles, values3, 'g', alpha=0.1)
plt.legend(fontsize =15)
plt.show()
# Out:
# [0.66222939 0.58431931 0.7706334  0.59689529 0.85190718 0.58269432
#  0.60889534 0.5563982  0.62285908 0.62675398 0.96639705 0.77583454
#  0.77138793 0.8465338  0.78299324 0.75111008 0.60587482 0.8490019
#  0.97007232 0.60693895 0.66275212 0.44234342 0.6853719  0.55238023
#  0.85761589 0.62454159 0.66494048 0.58213527 0.85850966 0.61881354
#  0.76096455 0.86521599 0.52423041 0.77178307 0.80668007 0.76964575
#  0.67077023 0.58887197 0.95352158 0.58412129 0.69269531 0.5562144
#  0.59293902 0.79000591 0.92584421 0.60273744 0.58797649 0.66865113
#  0.9697533  0.96855784 0.78732389 0.73665378 0.58719494 0.76785264
#  0.66434329 0.58282405]

# %%
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/wbm/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/wbm/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
test_metrics = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/wbm/test_perf_metrics.pkl','rb'))
# test_metrics_reverse = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/926save/0.25/morwbm/test_perf_metrics.pkl','rb'))
test_metrics_cmo = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/wbmcmo/test_perf_metrics.pkl','rb'))

# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
# number of variable
# 变量类别
plt.figure(figsize=(20,20))
categories = np.array(list(test_metrics[1]['next_timepoint_was_measured', 'AUROC (all)'].keys()))[:,0]
N = len(categories)
# plot the first line of the data frame.
values1 = test_metrics[1]['next_timepoint_was_measured', 'AUROC (all)'].values
values3 = test_metrics_cmo[1]['next_timepoint_was_measured', 'AUROC (all)'].values
# 将第一个值放到最后，以封闭图形
# print(values)

# 设置每个点的角度值
angles = [n / float(N) * 2 * pi for n in range(N)]
# angles += angles[:1]

# Initialise the spider plot
# 初始化极坐标网格
ax = plt.subplot(111, polar=True)

# Draw one axe per variable + add labels labels yet
# 设置x轴的标签
plt.xticks(angles[:-1], categories, color='red', size=10)

# Draw ylabels
# 设置标签显示位置
ax.set_rlabel_position(0)
# 设置y轴的标签
plt.yticks([0.5, 0.75, 1], ["0.5", "0.75", "1"], color="blue", size=15)
plt.ylim(0, 1)

# Plot data
# 画图
ax.plot(angles, values1, linewidth=1,label = 'wbm only', linestyle='solid')
# ax.plot(angles, values2, linewidth=1,label = 'wbm + mor reverse', linestyle='solid')
ax.plot(angles, values3, linewidth=1,label = 'wbm + cmo', linestyle='solid')
# Fill area
# 填充区域
ax.fill(angles, values1, 'b', alpha=0.1)
# ax.fill(angles, values2, 'r', alpha=0.1)
ax.fill(angles, values3, 'g', alpha=0.1)
plt.legend(fontsize =15)
plt.show()

# %%
np.array(list(test_metrics[1]['Final Acuity Outcome', 'AUROC (ovr; all)'].keys()))
# Out:
# array(['HOME HEALTH CARE', 'HOME', 'SNF', 'REHAB/DISTINCT PART HOSP',
#        'LONG TERM CARE HOSPITAL', 'DISC-TRAN CANCER/CHLDRN H',
#        'SHORT TERM HOSPITAL', 'DISCH-TRAN TO PSYCH HOSP', 'HOSPICE-HOME',
#        'LEFT AGAINST MEDICAL ADVI', 'HOSPICE-MEDICAL FACILITY',
#        'HOME WITH HOME IV PROVIDR', 'ICF', 'IN_ICU', 'IN_HOSPITAL'],
#       dtype='<U25')

# %%
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/acu/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/acu/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
test_metrics = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.75/acu/test_perf_metrics.pkl','rb'))
# test_metrics_reverse = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/926save/0.25/morwbm/test_perf_metrics.pkl','rb'))
test_metrics_cmo = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.75/acuwbm/test_perf_metrics.pkl','rb'))
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
# number of variable
# 变量类别
plt.figure(figsize=(20,20))
categories = np.array(list(test_metrics[1]['Final Acuity Outcome', 'AUROC (ovr; all)'].keys()))
N = len(categories)
# plot the first line of the data frame.
values1 = test_metrics[1]['Final Acuity Outcome', 'AUROC (ovr; all)'].values
values3 = test_metrics_cmo[1]['Final Acuity Outcome', 'AUROC (ovr; all)'].values
# 将第一个值放到最后，以封闭图形
# print(values)

# 设置每个点的角度值
angles = [n / float(N) * 2 * pi for n in range(N)]
# angles += angles[:1]

# Initialise the spider plot
# 初始化极坐标网格
ax = plt.subplot(111, polar=True)

# Draw one axe per variable + add labels labels yet
# 设置x轴的标签
plt.xticks(angles[:-1], categories, color='red', size=10)

# Draw ylabels
# 设置标签显示位置
ax.set_rlabel_position(0)
# 设置y轴的标签
plt.yticks([0.5, 0.75, 1], ["0.5", "0.75", "1"], color="blue", size=15)
plt.ylim(0, 1)

# Plot data
# 画图
ax.plot(angles, values1, linewidth=1,label = 'acu', linestyle='solid')
# ax.plot(angles, values2, linewidth=1,label = 'wbm + mor reverse', linestyle='solid')
ax.plot(angles, values3, linewidth=1,label = 'wbm + acu', linestyle='solid')
# Fill area
# 填充区域
ax.fill(angles, values1, 'b', alpha=0.1)
# ax.fill(angles, values2, 'r', alpha=0.1)
ax.fill(angles, values3, 'g', alpha=0.1)
plt.legend(fontsize =15)
plt.show()

# %%
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.75/wbm/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.75/wbm/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
test_metrics = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.75/wbm/test_perf_metrics.pkl','rb'))
# test_metrics_reverse = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/926save/0.25/morwbm/test_perf_metrics.pkl','rb'))
test_metrics_cmo = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.75/acuwbm/test_perf_metrics.pkl','rb'))
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
# number of variable
# 变量类别
plt.figure(figsize=(20,20))
categories = np.array(list(test_metrics[1]['next_timepoint_was_measured', 'AUROC (all)'].keys()))[:,0]
N = len(categories)
# plot the first line of the data frame.
values1 = test_metrics[1]['next_timepoint_was_measured', 'AUROC (all)'].values
values3 = test_metrics_cmo[1]['next_timepoint_was_measured', 'AUROC (all)'].values
# 将第一个值放到最后，以封闭图形
# print(values)

# 设置每个点的角度值
angles = [n / float(N) * 2 * pi for n in range(N)]
# angles += angles[:1]

# Initialise the spider plot
# 初始化极坐标网格
ax = plt.subplot(111, polar=True)

# Draw one axe per variable + add labels labels yet
# 设置x轴的标签
plt.xticks(angles[:-1], categories, color='red', size=10)

# Draw ylabels
# 设置标签显示位置
ax.set_rlabel_position(0)
# 设置y轴的标签
plt.yticks([0.5, 0.75, 1], ["0.5", "0.75", "1"], color="blue", size=15)
plt.ylim(0, 1)

# Plot data
# 画图
ax.plot(angles, values1, linewidth=1,label = 'wbm only', linestyle='solid')
# ax.plot(angles, values2, linewidth=1,label = 'wbm + mor reverse', linestyle='solid')
ax.plot(angles, values3, linewidth=1,label = 'wbm + acu', linestyle='solid')
# Fill area
# 填充区域
ax.fill(angles, values1, 'b', alpha=0.1)
# ax.fill(angles, values2, 'r', alpha=0.1)
ax.fill(angles, values3, 'g', alpha=0.1)
plt.legend(fontsize =15)
plt.show()

# %%
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/cmo/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/cmo/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
test_metrics = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/cmo/test_perf_metrics.pkl','rb'))
# test_metrics_reverse = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/926save/0.25/morwbm/test_perf_metrics.pkl','rb'))
test_metrics_cmo = pickle.load(open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/morcmo/test_perf_metrics.pkl','rb'))

# %%
test_metrics[1]['tasks_binary_multilabel', 'AUROC (all)']
# Out:
# mort_24h               0.732493
# mort_48h               0.566679
# dnr_24h                0.633478
# dnr_48h                0.413047
# cmo_24h                0.743800
# cmo_48h                0.698186
# Long LOS               0.541341
# icd_infection          0.593420
# icd_neoplasms          0.520819
# icd_endocrine          0.481477
# icd_blood              0.479942
# icd_mental             0.573780
# icd_nervous            0.471844
# icd_circulatory        0.535968
# icd_respiratory        0.414467
# icd_digestive          0.474905
# icd_genitourinary      0.446004
# icd_pregnancy          0.733283
# icd_skin               0.543949
# icd_musculoskeletal    0.539349
# icd_congenital         0.467078
# icd_perinatal               NaN
# icd_ill_defined        0.544930
# icd_injury             0.504600
# icd_unknown                 NaN
# Readmission 30         0.462455
# dtype: float64

# %%
import pickle
# test_perf_metrics.pkl
# test_reprs.pkl
# test_task_info.pkl
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/cmo/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/cmo/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
X = pr
y = t_info[1]['tasks_binary_multilabel'][1][:1024][:,4]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16,8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = t_info[1]['tasks_binary_multilabel'][0][:1024][:,4]
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()

# %%
import pickle
# test_perf_metrics.pkl
# test_reprs.pkl
# test_task_info.pkl
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/morcmo/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/morcmo/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
X = pr
y = t_info[1]['tasks_binary_multilabel'][1][:1024][:,4]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16,8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = t_info[1]['tasks_binary_multilabel'][0][:1024][:,4]
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()

# %%
import pickle
# test_perf_metrics.pkl
# test_reprs.pkl
# test_task_info.pkl
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/wbm/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/wbm/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
X = pr
y = t_info[1]['next_timepoint_was_measured'][1][:1024][:,44]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16,8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = t_info[1]['next_timepoint_was_measured'][0][:1024][:,44]
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()

# %%
import pickle
# test_perf_metrics.pkl
# test_reprs.pkl
# test_task_info.pkl
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/morwbm/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/morwbm/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
X = pr
y = t_info[1]['next_timepoint_was_measured'][1][:1024][:,44]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16,8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = t_info[1]['next_timepoint_was_measured'][0][:1024][:,44]
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()

# %%
import pickle
# test_perf_metrics.pkl
# test_reprs.pkl
# test_task_info.pkl
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.01/cmo/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.01/cmo/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
X = pr
y = t_info[1]['tasks_binary_multilabel'][1][:1024][:,4]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16,8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = t_info[1]['tasks_binary_multilabel'][0][:1024][:,4]
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()
import pickle
# test_perf_metrics.pkl
# test_reprs.pkl
# test_task_info.pkl
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/1/0.01/morcmo/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/1/0.01/morcmo/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
X = pr
y = t_info[1]['tasks_binary_multilabel'][1][:1024][:,4]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16,8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = t_info[1]['tasks_binary_multilabel'][0][:1024][:,4]
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()

# %%
import pickle
# test_perf_metrics.pkl
# test_reprs.pkl
# test_task_info.pkl
test_pr = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/morwbm/test_reprs.pkl','rb')
pr = pickle.load(test_pr)[1][0][1]
task_info = open('/home/covpreduser/Blob/v-xiaosong/comprehensive_MTL_EHR/Sample Args/920save/split0/0/0.25/morwbm/test_task_info.pkl','rb')
t_info = pickle.load(task_info)
X = pr
y = t_info[1]['next_timepoint_was_measured'][1][:1024][:,44]
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold,datasets
tsne = manifold.TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)  # 归一化
plt.figure(figsize=(16,8))
plt.subplot(121)
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
# plt.figure(figsize=(8, 8))
plt.subplot(122)
y = t_info[1]['next_timepoint_was_measured'][0][:1024][:,44]
for i in range(X_norm.shape[0]):
    plt.scatter(X_norm[i, 0], X_norm[i, 1], color=plt.cm.Set1(y[i]) )
plt.show()
